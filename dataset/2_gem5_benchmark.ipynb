# %%
import argparse
import os 
import logging 
import json
import re
import glob
import time 
import traceback
import subprocess
import shlex
import resource
from tqdm import tqdm 
import shutil
import ast 
import sys

# %%
MAX_VIRTUAL_MEMORY = 10 * 1024 * 1024 * 50  # 500 MB
def limit_virtual_memory():
    resource.setrlimit(resource.RLIMIT_AS, (MAX_VIRTUAL_MEMORY*2, MAX_VIRTUAL_MEMORY * 10))

# %%
TARGET_PROJECT = "/data3/tydata3/code_optimization/cpp/"
INPUT_PROJECT = "/home/tongye/code_generation/pie-perf/data/"
MERGED_TEST_CASES = "/home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/"
MAX_TESTCASES=3

# %%
from argparse import Namespace

args = Namespace(
    output_dir = TARGET_PROJECT,
    input_dir = INPUT_PROJECT,
    split = "test",
    language = 'cpp',
    cstd = 'std=c++17',
    optimization_flag = '-O3',
    timeout_seconds_binary = 10,
    timeout_seconds_gem5 = 120,
    gem5_opt = '/home/tongye/code_generation/gem5/build/X86/gem5.opt',
    gem5_script_path = '/home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py',
    cpu_type = 'Verbatim'
)

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)

file_handler = logging.FileHandler("benchmark.log")
file_handler.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.propagate = False

# %%
def execute_bin(args, bin_file_path, input_case_path):
    logger.info(f"Binary executing {bin_file_path}, with input {input_case_path}")
    with open(input_case_path, 'r') as fh:
        p = subprocess.run([bin_file_path],
                           preexec_fn=limit_virtual_memory,
                           bufsize=MAX_VIRTUAL_MEMORY,
                           capture_output=True,
                           timeout=args.timeout_seconds_binary,
                           stdin=fh,
                           text=True,
                           )
        returncode = p.returncode
        stdout = p.stdout
        stderr = p.stderr
    
    return returncode, stdout, stderr

# %%
def execute_gem5(args, bin_file_path, input_case_path, gem5_stats_out_path):
    cmd = f"{args.gem5_opt} --stats-file={gem5_stats_out_path} {args.gem5_script_path} {args.cpu_type} {bin_file_path}"
    logger.info(f'GEM5 executing {cmd}, with input {input_case_path}')
    cmd_args = shlex.split(cmd)
    with open(input_case_path, 'r') as fh:
        p = subprocess.run(cmd_args,
                           capture_output=True,
                           bufsize=MAX_VIRTUAL_MEMORY,
                           timeout=args.timeout_seconds_gem5,
                           stdin=fh,
                           text=True
                           )
        returncode = p.returncode
        stdout = p.stdout
        stderr = p.stderr
    
    return returncode, stdout, stderr

# %%
def benchmark_single_file(args, problem_id, bin_file_path, gem5_out_path):
    assert os.path.isdir(gem5_out_path),  f"{gem5_out_path} not exist!"

    test_cases_results = []
    test_cases_dir_in_problem_id = os.path.join(MERGED_TEST_CASES, problem_id)
    input_cases_paths = glob.glob(os.path.join(test_cases_dir_in_problem_id, 'input.*.txt'))
    # in_paths: list
    for input_case_path in input_cases_paths[:MAX_TESTCASES]: # for each input case
        # print(input_case_path)
        test_case_id = re.search('input\.([0-9]+)\.txt', input_case_path).group(1)
        gem5_stats_out_path = os.path.join(gem5_out_path, f'gem5_stats.{test_case_id}.txt')

        start_time = time.time()

        returncode_bin = returncode_gem5 =  -1
        stdout_bin, stderr_bin, stdout_gem5, stderr_gem5 = '', '', '', ''
        error_info = ''

        try:
            returncode_bin, stdout_bin, stderr_bin = execute_bin(args, bin_file_path, input_case_path)
            if returncode_bin != 0:
                raise Exception(f"Binary execution FAILED for {bin_file_path} with {input_case_path} with stderr {stderr_bin}")
            
            returncode_gem5, stdout_gem5, stderr_gem5 = execute_gem5(args, bin_file_path, input_case_path, gem5_stats_out_path)
            if returncode_gem5 != 0:
                raise Exception(f"gem5 execution FAILED for {bin_file_path} with {input_case_path} with stderr {stderr_gem5}")
            
            logger.info(f"BINARY execution and GEM5 execution SUCCEEDED for {bin_file_path} with {input_case_path}")

        except Exception as e:
            error_info = str(e) + traceback.format_exc()
            logger.warning(f"Execution FAILED with exception {str(error_info)} for {bin_file_path} with {input_case_path}")

        end_time = time.time()
        test_case_result = {
            'bin_file_path': bin_file_path,
            'input_case_path': input_case_path,
            'returncode': 0 if (returncode_bin == 0 and returncode_gem5 == 0) else -100,
            'test_case_id': test_case_id,
            'returncode_bin': returncode_bin,
            'stdout_bin': stdout_bin,
            'stderr_bin': stderr_bin,
            'returncode_gem5': returncode_gem5,
            'stdout_gem5': stdout_gem5,
            'stderr_gem5': stderr_gem5,
            'gem5_stats_out_path': gem5_stats_out_path,
            'time': end_time - start_time,
            'error_info': error_info,
        }
        test_cases_results.append(test_case_result)

    return test_cases_results

# %%
def benchmark(args):
    binary_dir = os.path.join(args.output_dir, "cpp_binary", f"{args.split}_out")
    logger.info(f"cpp binary dir path  = {binary_dir}")

    binary_files = glob.glob(binary_dir + "/*.out")
    logger.info(f"There are {len(binary_files)} binary out.")
    
    for binary in tqdm(binary_files[:3], desc="Benchmarking:"):  # for each binary out

        pattern_problem_id = r'p\d+'
        pattern_submission_id = r's\d+'
        pattern_user_id = r'u\d+'

        match_problem_id = re.search(pattern_problem_id, binary)
        match_submission_id = re.search(pattern_submission_id, binary)
        match_user_id = re.search(pattern_user_id, binary)

        if match_problem_id and match_submission_id and match_user_id:
            problem_id = match_problem_id.group()
            submission_id = match_submission_id.group()
            user_id = match_user_id.group()
        else:
            raise ValueError("problem_id or submission_id or user_id does not exist!")

        logger.info(f"Problem id = {problem_id} | User id = {user_id} | Submission id = {submission_id}")

        # creat dir to store gem5 output
        # code_optimization → cpp → benchmark_gem5 → train/val/test_out 
        # → problem_id → user_id → submission_id → stat_testcaseid.txt
        gem5_out_path = os.path.join(TARGET_PROJECT, "benchmark_gem5_all_testcases", f"{args.split}_out", problem_id, user_id, submission_id)
        if not os.path.isdir(gem5_out_path):
            os.makedirs(gem5_out_path)

        test_cases_results = benchmark_single_file(args, problem_id, binary, gem5_out_path)
        # (test_cases_results)
        with open(os.path.join(gem5_out_path, f"testcases_all_benchmark_results.json"), 'w') as g:
            json.dump(test_cases_results, g, indent=4)

    return None

# %%
benchmark(args)
# Out:
# INFO:root:cpp binary dir path  = /data3/tydata3/code_optimization/cpp/cpp_binary/test_out
# INFO:root:There are 9694 binary out.
# Benchmarking::   0%|          | 0/3 [00:00<?, ?it/s]INFO:root:Problem id = p02898 | User id = u398394831 | Submission id = s770504383
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.6.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02898/u398394831/s770504383/gem5_stats.6.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.6.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.6.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.32.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02898/u398394831/s770504383/gem5_stats.32.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.32.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.32.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.5.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02898/u398394831/s770504383/gem5_stats.5.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.5.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02898_s770504383_u398394831.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02898/input.5.txt
# Benchmarking::  33%|███▎      | 1/3 [00:42<01:24, 42.18s/it]INFO:root:Problem id = p03730 | User id = u563788821 | Submission id = s153858929
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.6.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p03730/u563788821/s153858929/gem5_stats.6.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.6.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.6.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.32.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p03730/u563788821/s153858929/gem5_stats.32.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.32.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.32.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.5.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p03730/u563788821/s153858929/gem5_stats.5.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.5.txt
# INFO:root:BINARY execution and GEM5 execution SUCCEEDED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p03730_s153858929_u563788821.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p03730/input.5.txt
# Benchmarking::  67%|██████▋   | 2/3 [01:24<00:42, 42.02s/it]INFO:root:Problem id = p02986 | User id = u301030835 | Submission id = s599276197
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.6.txt
# WARNING:root:Execution FAILED with exception Command '['/data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out']' timed out after 10 secondsTraceback (most recent call last):
#   File "/tmp/ipykernel_2086204/3926632540.py", line 20, in benchmark_single_file
#     returncode_bin, stdout_bin, stderr_bin = execute_bin(args, bin_file_path, input_case_path)
#   File "/tmp/ipykernel_2086204/260136340.py", line 4, in execute_bin
#     p = subprocess.run([bin_file_path],
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 2022, in _communicate
#     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 1198, in _check_timeout
#     raise TimeoutExpired(
# subprocess.TimeoutExpired: Command '['/data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out']' timed out after 10 seconds
#  for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.6.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.32.txt
# INFO:root:GEM5 executing /home/tongye/code_generation/gem5/build/X86/gem5.opt --stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02986/u301030835/s599276197/gem5_stats.32.txt /home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py Verbatim /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.32.txt
# WARNING:root:Execution FAILED with exception Command '['/home/tongye/code_generation/gem5/build/X86/gem5.opt', '--stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02986/u301030835/s599276197/gem5_stats.32.txt', '/home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py', 'Verbatim', '/data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out']' timed out after 120 secondsTraceback (most recent call last):
#   File "/tmp/ipykernel_2086204/3926632540.py", line 24, in benchmark_single_file
#     returncode_gem5, stdout_gem5, stderr_gem5 = execute_gem5(args, bin_file_path, input_case_path, gem5_stats_out_path)
#   File "/tmp/ipykernel_2086204/1990133800.py", line 6, in execute_gem5
#     p = subprocess.run(cmd_args,
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 2022, in _communicate
#     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#   File "/home/tongye/anaconda3/envs/llama/lib/python3.10/subprocess.py", line 1198, in _check_timeout
#     raise TimeoutExpired(
# subprocess.TimeoutExpired: Command '['/home/tongye/code_generation/gem5/build/X86/gem5.opt', '--stats-file=/data3/tydata3/code_optimization/cpp/benchmark_gem5_all_testcases/test_out/p02986/u301030835/s599276197/gem5_stats.32.txt', '/home/tongye/code_generation/gem5-skylake-config/gem5-configs/run-se.py', 'Verbatim', '/data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out']' timed out after 120 seconds
#  for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.32.txt
# INFO:root:Binary executing /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out, with input /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.5.txt
# WARNING:root:Execution FAILED with exception Binary execution FAILED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.5.txt with stderr Traceback (most recent call last):
#   File "/tmp/ipykernel_2086204/3926632540.py", line 22, in benchmark_single_file
#     raise Exception(f"Binary execution FAILED for {bin_file_path} with {input_case_path} with stderr {stderr_bin}")
# Exception: Binary execution FAILED for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.5.txt with stderr
#  for /data3/tydata3/code_optimization/cpp/cpp_binary/test_out/p02986_s599276197_u301030835.out with /home/tongye/code_generation/pie-perf/data/test_cases/merged_test_cases/p02986/input.5.txt
# Benchmarking:: 100%|██████████| 3/3 [03:34<00:00, 71.42s/it]
